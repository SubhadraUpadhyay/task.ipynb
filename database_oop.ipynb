# %% [markdown]
# Required imports

# %%
from sqlalchemy.engine import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float

# %% [markdown]
# required boilerplate code

# %%
Base = declarative_base()

# %% [markdown]
# your database table

# %%
class Student(Base):
    __tablename__ = 'students'
    id = Column(Integer, primary_key=True)
    name = Column(String(50))
    klass = Column(Integer)

# %% [markdown]
# database creation

# %%
engine = create_engine("sqlite:///school.sqlite")
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# DatabaseError: file is not a database
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# c:\Users\ANURAG UPADHYAY\Documents\digi\database_oop.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ANURAG%20UPADHYAY/Documents/digi/database_oop.ipynb#ch0000007?line=0'>1</a> engine = create_engine("sqlite:///school.sqlite")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ANURAG%20UPADHYAY/Documents/digi/database_oop.ipynb#ch0000007?line=1'>2</a> Base.metadata.create_all(engine)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\schema.py:4864, in MetaData.create_all(self, bind, tables, checkfirst)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4861'>4862</a> if bind is None:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4862'>4863</a>     bind = _bind_or_error(self)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4863'>4864</a> bind._run_ddl_visitor(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4864'>4865</a>     ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4865'>4866</a> )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:3123, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3120'>3121</a> def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3121'>3122</a>     with self.begin() as conn:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3122'>3123</a>         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:2119, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2111'>2112</a> def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2112'>2113</a>     """run a DDL visitor.
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2113'>2114</a>
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2114'>2115</a>     This method is only here so that the MockConnection can change the
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2115'>2116</a>     options given to the visitor so that "checkfirst" is skipped.
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2116'>2117</a>
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2117'>2118</a>     """
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2118'>2119</a>     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\visitors.py:524, in ExternalTraversal.traverse_single(self, obj, **kw)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/visitors.py?line=521'>522</a> meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/visitors.py?line=522'>523</a> if meth:
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/visitors.py?line=523'>524</a>     return meth(obj, **kw)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\ddl.py:826, in SchemaGenerator.visit_metadata(self, metadata)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=821'>822</a> else:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=822'>823</a>     tables = list(metadata.tables.values())
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=824'>825</a> collection = sort_tables_and_constraints(
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=825'>826</a>     [t for t in tables if self._can_create_table(t)]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=826'>827</a> )
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=828'>829</a> seq_coll = [
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=829'>830</a>     s
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=830'>831</a>     for s in metadata._sequences.values()
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=831'>832</a>     if s.column is None and self._can_create_sequence(s)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=832'>833</a> ]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=834'>835</a> event_collection = [t for (t, fks) in collection if t is not None]
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\ddl.py:826, in <listcomp>(.0)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=821'>822</a> else:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=822'>823</a>     tables = list(metadata.tables.values())
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=824'>825</a> collection = sort_tables_and_constraints(
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=825'>826</a>     [t for t in tables if self._can_create_table(t)]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=826'>827</a> )
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=828'>829</a> seq_coll = [
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=829'>830</a>     s
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=830'>831</a>     for s in metadata._sequences.values()
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=831'>832</a>     if s.column is None and self._can_create_sequence(s)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=832'>833</a> ]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=834'>835</a> event_collection = [t for (t, fks) in collection if t is not None]
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\ddl.py:791, in SchemaGenerator._can_create_table(self, table)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=788'>789</a> if effective_schema:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=789'>790</a>     self.dialect.validate_identifier(effective_schema)
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=790'>791</a> return not self.checkfirst or not self.dialect.has_table(
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=791'>792</a>     self.connection, table.name, schema=effective_schema
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=792'>793</a> )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:2018, in SQLiteDialect.has_table(self, connection, table_name, schema)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2014'>2015</a> def has_table(self, connection, table_name, schema=None):
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2015'>2016</a>     self._ensure_has_table_connection(connection)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2017'>2018</a>     info = self._get_table_pragma(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2018'>2019</a>         connection, "table_info", table_name, schema=schema
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2019'>2020</a>     )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2020'>2021</a>     return bool(info)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:2541, in SQLiteDialect._get_table_pragma(self, connection, pragma, table_name, schema)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2538'>2539</a> for statement in statements:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2539'>2540</a>     statement = "%s%s(%s)" % (statement, pragma, qtable)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2540'>2541</a>     cursor = connection.exec_driver_sql(statement)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2541'>2542</a>     if not cursor._soft_closed:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2542'>2543</a>         # work around SQLite issue whereby cursor.description
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2543'>2544</a>         # is blank when PRAGMA returns no rows:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2544'>2545</a>         # https://www.sqlite.org/cvstrac/tktview?tn=1884
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2545'>2546</a>         result = cursor.fetchall()
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1675, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1624'>1625</a> r"""Executes a SQL statement construct and returns a
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1625'>1626</a> :class:`_engine.CursorResult`.
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1626'>1627</a>
#    (...)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1669'>1670</a>
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1670'>1671</a> """
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1672'>1673</a> args_10style, kwargs_10style = _distill_params_20(parameters)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1674'>1675</a> return self._exec_driver_sql(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1675'>1676</a>     statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1676'>1677</a>     args_10style,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1677'>1678</a>     kwargs_10style,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1678'>1679</a>     execution_options,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1679'>1680</a>     future=True,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1680'>1681</a> )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1584, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1573'>1574</a>         (
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1574'>1575</a>             statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1575'>1576</a>             distilled_params,
#    (...)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1579'>1580</a>             statement, distilled_parameters, execution_options
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1580'>1581</a>         )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1582'>1583</a> dialect = self.dialect
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1583'>1584</a> ret = self._execute_context(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1584'>1585</a>     dialect,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1585'>1586</a>     dialect.execution_ctx_cls._init_statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1586'>1587</a>     statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1587'>1588</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1588'>1589</a>     execution_options,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1589'>1590</a>     statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1590'>1591</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1591'>1592</a> )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1593'>1594</a> if not future:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1594'>1595</a>     if self._has_events or self.engine._has_events:
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1847'>1848</a>             branched.close()
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1849'>1850</a> except BaseException as e:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1850'>1851</a>     self._handle_dbapi_exception(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1851'>1852</a>         e, statement, parameters, cursor, context
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1852'>1853</a>     )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1854'>1855</a> return result
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2030'>2031</a> elif should_wrap:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2031'>2032</a>     util.raise_(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2032'>2033</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2033'>2034</a>     )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2034'>2035</a> else:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2035'>2036</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1805'>1806</a>                 break
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1812'>1813</a>     self.dispatch.after_cursor_execute(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1813'>1814</a>         self,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1814'>1815</a>         cursor,
#    (...)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1818'>1819</a>         context.executemany,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1819'>1820</a>     )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# DatabaseError: (sqlite3.DatabaseError) file is not a database
# [SQL: PRAGMA main.table_info("students")]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)

# %%
engine = create_engine("sqlite:///school.sqlite")
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# DatabaseError: file is not a database
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# c:\Users\ANURAG UPADHYAY\Documents\digi\database_oop.ipynb Cell 9' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ANURAG%20UPADHYAY/Documents/digi/database_oop.ipynb#ch0000011?line=0'>1</a> engine = create_engine("sqlite:///school.sqlite")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ANURAG%20UPADHYAY/Documents/digi/database_oop.ipynb#ch0000011?line=1'>2</a> Base.metadata.create_all(engine)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\schema.py:4864, in MetaData.create_all(self, bind, tables, checkfirst)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4861'>4862</a> if bind is None:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4862'>4863</a>     bind = _bind_or_error(self)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4863'>4864</a> bind._run_ddl_visitor(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4864'>4865</a>     ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/schema.py?line=4865'>4866</a> )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:3123, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3120'>3121</a> def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3121'>3122</a>     with self.begin() as conn:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3122'>3123</a>         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:2119, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2111'>2112</a> def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2112'>2113</a>     """run a DDL visitor.
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2113'>2114</a>
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2114'>2115</a>     This method is only here so that the MockConnection can change the
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2115'>2116</a>     options given to the visitor so that "checkfirst" is skipped.
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2116'>2117</a>
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2117'>2118</a>     """
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2118'>2119</a>     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\visitors.py:524, in ExternalTraversal.traverse_single(self, obj, **kw)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/visitors.py?line=521'>522</a> meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/visitors.py?line=522'>523</a> if meth:
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/visitors.py?line=523'>524</a>     return meth(obj, **kw)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\ddl.py:826, in SchemaGenerator.visit_metadata(self, metadata)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=821'>822</a> else:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=822'>823</a>     tables = list(metadata.tables.values())
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=824'>825</a> collection = sort_tables_and_constraints(
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=825'>826</a>     [t for t in tables if self._can_create_table(t)]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=826'>827</a> )
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=828'>829</a> seq_coll = [
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=829'>830</a>     s
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=830'>831</a>     for s in metadata._sequences.values()
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=831'>832</a>     if s.column is None and self._can_create_sequence(s)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=832'>833</a> ]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=834'>835</a> event_collection = [t for (t, fks) in collection if t is not None]
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\ddl.py:826, in <listcomp>(.0)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=821'>822</a> else:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=822'>823</a>     tables = list(metadata.tables.values())
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=824'>825</a> collection = sort_tables_and_constraints(
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=825'>826</a>     [t for t in tables if self._can_create_table(t)]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=826'>827</a> )
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=828'>829</a> seq_coll = [
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=829'>830</a>     s
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=830'>831</a>     for s in metadata._sequences.values()
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=831'>832</a>     if s.column is None and self._can_create_sequence(s)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=832'>833</a> ]
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=834'>835</a> event_collection = [t for (t, fks) in collection if t is not None]
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\sql\ddl.py:791, in SchemaGenerator._can_create_table(self, table)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=788'>789</a> if effective_schema:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=789'>790</a>     self.dialect.validate_identifier(effective_schema)
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=790'>791</a> return not self.checkfirst or not self.dialect.has_table(
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=791'>792</a>     self.connection, table.name, schema=effective_schema
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/sql/ddl.py?line=792'>793</a> )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:2018, in SQLiteDialect.has_table(self, connection, table_name, schema)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2014'>2015</a> def has_table(self, connection, table_name, schema=None):
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2015'>2016</a>     self._ensure_has_table_connection(connection)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2017'>2018</a>     info = self._get_table_pragma(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2018'>2019</a>         connection, "table_info", table_name, schema=schema
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2019'>2020</a>     )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2020'>2021</a>     return bool(info)
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:2541, in SQLiteDialect._get_table_pragma(self, connection, pragma, table_name, schema)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2538'>2539</a> for statement in statements:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2539'>2540</a>     statement = "%s%s(%s)" % (statement, pragma, qtable)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2540'>2541</a>     cursor = connection.exec_driver_sql(statement)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2541'>2542</a>     if not cursor._soft_closed:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2542'>2543</a>         # work around SQLite issue whereby cursor.description
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2543'>2544</a>         # is blank when PRAGMA returns no rows:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2544'>2545</a>         # https://www.sqlite.org/cvstrac/tktview?tn=1884
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/dialects/sqlite/base.py?line=2545'>2546</a>         result = cursor.fetchall()
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1675, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1624'>1625</a> r"""Executes a SQL statement construct and returns a
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1625'>1626</a> :class:`_engine.CursorResult`.
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1626'>1627</a>
#    (...)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1669'>1670</a>
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1670'>1671</a> """
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1672'>1673</a> args_10style, kwargs_10style = _distill_params_20(parameters)
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1674'>1675</a> return self._exec_driver_sql(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1675'>1676</a>     statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1676'>1677</a>     args_10style,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1677'>1678</a>     kwargs_10style,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1678'>1679</a>     execution_options,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1679'>1680</a>     future=True,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1680'>1681</a> )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1584, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1573'>1574</a>         (
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1574'>1575</a>             statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1575'>1576</a>             distilled_params,
#    (...)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1579'>1580</a>             statement, distilled_parameters, execution_options
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1580'>1581</a>         )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1582'>1583</a> dialect = self.dialect
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1583'>1584</a> ret = self._execute_context(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1584'>1585</a>     dialect,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1585'>1586</a>     dialect.execution_ctx_cls._init_statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1586'>1587</a>     statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1587'>1588</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1588'>1589</a>     execution_options,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1589'>1590</a>     statement,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1590'>1591</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1591'>1592</a> )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1593'>1594</a> if not future:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1594'>1595</a>     if self._has_events or self.engine._has_events:
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1847'>1848</a>             branched.close()
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1849'>1850</a> except BaseException as e:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1850'>1851</a>     self._handle_dbapi_exception(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1851'>1852</a>         e, statement, parameters, cursor, context
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1852'>1853</a>     )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1854'>1855</a> return result
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2030'>2031</a> elif should_wrap:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2031'>2032</a>     util.raise_(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2032'>2033</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2033'>2034</a>     )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2034'>2035</a> else:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2035'>2036</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1805'>1806</a>                 break
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1812'>1813</a>     self.dispatch.after_cursor_execute(
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1813'>1814</a>         self,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1814'>1815</a>         cursor,
#    (...)
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1818'>1819</a>         context.executemany,
#    <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1819'>1820</a>     )
#
# File ~\miniconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/ANURAG%20UPADHYAY/miniconda3/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# DatabaseError: (sqlite3.DatabaseError) file is not a database
# [SQL: PRAGMA main.table_info("students")]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)
